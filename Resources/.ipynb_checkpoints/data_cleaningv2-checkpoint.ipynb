# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df_readcsv=pd.read_csv('MCI_2014_to_2018.csv')

# %%
df_readcsv.head()
# Out:
#            X          Y  Index_ event_unique_id            occurrencedate  \
# 0 -79.385193  43.659229    2349  GO-20149004286  2014-06-20T10:55:00.000Z
# 1 -79.425400  43.777592    2350  GO-20142411379  2014-07-02T00:20:00.000Z
# 2 -79.425400  43.777592    2351  GO-20142411379  2014-07-02T00:20:00.000Z
# 3 -79.210373  43.801727    2352  GO-20142412127  2014-07-02T01:30:00.000Z
# 4 -79.254334  43.835884    2354  GO-20142417548  2014-07-02T20:52:00.000Z
#
#                reporteddate premisetype  ucr_code  ucr_ext  \
# 0  2014-06-20T13:20:00.000Z   Apartment      2130      210
# 1  2014-07-02T02:58:00.000Z     Outside      1457      100
# 2  2014-07-02T02:58:00.000Z     Outside      1610      100
# 3  2014-07-02T05:40:00.000Z       House      2120      200
# 4  2014-07-02T20:57:00.000Z  Commercial      1430      100
#
#                offence  ...  occurrencedayofyear occurrencedayofweek  \
# 0           Theft Over  ...                171.0          Friday
# ...

# %%
new_df = df_readcsv.drop(columns=['X', 'Y', 'Index_', 'event_unique_id', 'ObjectId'])

# %%
new_df
# Out:
#                   occurrencedate              reporteddate premisetype  \
# 0       2014-06-20T10:55:00.000Z  2014-06-20T13:20:00.000Z   Apartment
# 1       2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside
# 2       2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside
# 3       2014-07-02T01:30:00.000Z  2014-07-02T05:40:00.000Z       House
# 4       2014-07-02T20:52:00.000Z  2014-07-02T20:57:00.000Z  Commercial
# 5       2014-07-18T00:01:00.000Z  2014-07-18T17:36:00.000Z       House
# 6       2014-07-18T23:15:00.000Z  2014-07-18T23:15:00.000Z       House
# 7       2014-07-19T01:30:00.000Z  2014-07-19T11:58:00.000Z     Outside
# 8       2014-07-19T15:00:00.000Z  2014-07-19T22:11:00.000Z       House
# 9       2014-07-20T01:30:00.000Z  2014-07-20T16:33:00.000Z       Other
# 10      2014-07-26T21:55:00.000Z  2014-07-26T21:57:00.000Z  Commercial
# 11      2014-08-09T01:05:00.000Z  2014-08-09T01:05:00.000Z   Apartment
# ...

# %%
export_csv = new_df.to_csv (r'cleaned_dataframe.csv', index = None, header=True)

# %%
#html = new_df.to_html()
#print(html)

# %%
df2=pd.read_csv('cleaned_dataframe.csv')

# %%
df2.head()
# Out:
#              occurrencedate              reporteddate premisetype  ucr_code  \
# 0  2014-06-20T10:55:00.000Z  2014-06-20T13:20:00.000Z   Apartment      2130
# 1  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1457
# 2  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1610
# 3  2014-07-02T01:30:00.000Z  2014-07-02T05:40:00.000Z       House      2120
# 4  2014-07-02T20:52:00.000Z  2014-07-02T20:57:00.000Z  Commercial      1430
#
#    ucr_ext              offence  reportedyear reportedmonth  reportedday  \
# 0      210           Theft Over          2014          June           20
# 1      100   Pointing A Firearm          2014          July            2
# 2      100  Robbery With Weapon          2014          July            2
# 3      200                  B&E          2014          July            2
# 4      100              Assault          2014          July            2
#
#    reporteddayofyear  ... occurrenceday  occurrencedayofyear  \
# ...

# %%
x=df2.to_html('test2.txt')
