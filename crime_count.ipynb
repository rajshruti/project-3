# %%
import pandas as pd

# %%
df= pd.read_csv('cleaned_dataframe.csv')

# %%
df.head()
# Out:
#              occurrencedate              reporteddate premisetype  ucr_code  \
# 0  2014-06-20T10:55:00.000Z  2014-06-20T13:20:00.000Z   Apartment      2130
# 1  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1457
# 2  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1610
# 3  2014-07-02T01:30:00.000Z  2014-07-02T05:40:00.000Z       House      2120
# 4  2014-07-02T20:52:00.000Z  2014-07-02T20:57:00.000Z  Commercial      1430
#
#    ucr_ext              offence  reportedyear reportedmonth  reportedday  \
# 0      210           Theft Over          2014          June           20
# 1      100   Pointing A Firearm          2014          July            2
# 2      100  Robbery With Weapon          2014          July            2
# 3      200                  B&E          2014          July            2
# 4      100              Assault          2014          July            2
#
#    reporteddayofyear  ... occurrenceday  occurrencedayofyear  \
# ...

# %%
df['occurrencemonth'].head()
# Out:
# 0    June
# 1    July
# 2    July
# 3    July
# 4    July
# Name: occurrencemonth, dtype: object

# %%
df[['occurrencemonth','occurrenceyear']].head()
# Out:
#   occurrencemonth  occurrenceyear
# 0            June          2014.0
# 1            July          2014.0
# 2            July          2014.0
# 3            July          2014.0
# 4            July          2014.0

# %%
type(df.occurrenceyear)
# Out:
# pandas.core.series.Series

# %%
df = df.sort_values(by=['occurrencemonth'])

# %%
crime_count= df.groupby(['occurrenceyear', 'occurrencemonth']).size()

# %%
crime_count
# Out:
# occurrenceyear  occurrencemonth
# 2000.0          August                1
#                 February              1
#                 January               9
#                 November              1
#                 October               2
# 2001.0          April                 2
#                 January               4
#                 July                  2
#                 November              1
#                 October               3
# 2002.0          April                 1
#                 January               2
#                 July                  1
#                 March                 1
#                 September             2
# 2003.0          January               7
#                 May                   1
#                 September             1
# 2004.0          February              2
#                 January               5
#                 May                   1
#                 October               1
#                 September             3
# ...

# %%
count= crime_count.loc[2014.0:2018.0]

# %%
count
# Out:
# occurrenceyear  occurrencemonth
# 2014.0          April              2510
#                 August             2763
#                 December           2472
#                 February           2197
#                 January            2443
#                 July               2669
#                 June               2778
#                 March              2422
#                 May                2856
#                 November           2777
#                 October            2903
#                 September          2838
# 2015.0          April              2603
#                 August             2911
#                 December           2743
#                 February           2100
#                 January            2430
#                 July               2885
#                 June               2818
#                 March              2398
#                 May                2840
#                 November           2826
#                 October            2893
# ...

# %%
type(count)
# Out:
# pandas.core.series.Series

# %%
count.to_frame()
# Out:
#                                    0
# occurrenceyear occurrencemonth
# 2014.0         April            2510
#                August           2763
#                December         2472
#                February         2197
#                January          2443
#                July             2669
#                June             2778
#                March            2422
#                May              2856
#                November         2777
#                October          2903
#                September        2838
# 2015.0         April            2603
#                August           2911
#                December         2743
#                February         2100
#                January          2430
#                July             2885
#                June             2818
#                March            2398
#                May              2840
#                November         2826
#                October          2893
# ...

# %%
count.to_csv('crimecount.csv',header=['count'])
