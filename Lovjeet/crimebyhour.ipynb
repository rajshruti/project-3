# %%
import pandas as pd

# %%
df= pd.read_csv('cleaned_dataframe.csv')

# %%
df.head()
# Out:
#              occurrencedate              reporteddate premisetype  ucr_code  \
# 0  2014-06-20T10:55:00.000Z  2014-06-20T13:20:00.000Z   Apartment      2130
# 1  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1457
# 2  2014-07-02T00:20:00.000Z  2014-07-02T02:58:00.000Z     Outside      1610
# 3  2014-07-02T01:30:00.000Z  2014-07-02T05:40:00.000Z       House      2120
# 4  2014-07-02T20:52:00.000Z  2014-07-02T20:57:00.000Z  Commercial      1430
#
#    ucr_ext              offence  reportedyear reportedmonth  reportedday  \
# 0      210           Theft Over          2014          June           20
# 1      100   Pointing A Firearm          2014          July            2
# 2      100  Robbery With Weapon          2014          July            2
# 3      200                  B&E          2014          July            2
# 4      100              Assault          2014          July            2
#
#    reporteddayofyear  ... occurrenceday  occurrencedayofyear  \
# ...

# %%
df['occurrencedayofweek'].head()
# Out:
# 0    Friday
# 1    Wednesday
# 2    Wednesday
# 3    Wednesday
# 4    Wednesday
# Name: occurrencedayofweek, dtype: object

# %%
df[['occurrenceyear','occurrencedayofweek','occurrencehour']].head()
# Out:
#         occurrenceyear occurrencedayofweek  occurrencehour
# 128570          2017.0          Friday                   9
# 151464          2014.0          Friday                  20
# 108276          2015.0          Friday                  15
# 154888          2014.0          Friday                  20
# 33083           2014.0          Friday                  22

# %%
type(df.occurrencehour)
# Out:
# pandas.core.series.Series

# %%
df = df.sort_values(by=['occurrenceyear'])

# %%
crime_byhour= df.groupby(['occurrenceyear','occurrencedayofweek','occurrencehour']).size()

# %%
crime_count= crime_byhour.loc[2014.0:2018.0]

# %%
crime_count
# Out:
# occurrenceyear  occurrencedayofweek  occurrencehour
# 2014.0          Friday               0                 263
#                                      1                 159
#                                      2                 163
#                                      3                 124
#                                      4                  84
#                                                       ...
# 2018.0          Wednesday            19                267
#                                      20                291
#                                      21                285
#                                      22                269
#                                      23                286
# Length: 840, dtype: int64

# %%
crime_count.to_frame()
# Out:
#                                                      0
# occurrenceyear occurrencedayofweek occurrencehour
# 2014.0         Friday              0               263
#                                    1               159
#                                    2               163
#                                    3               124
#                                    4                84
# ...                                                ...
# 2018.0         Wednesday           19              267
#                                    20              291
#                                    21              285
#                                    22              269
#                                    23              286
#
# [840 rows x 1 columns]

# %%
crime_count.to_csv('crime_byhour.csv',header=['count'])
